# %%
import pandas as pd
data = pd.read_csv('housing.csv')
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
medIncome = data['median_income']
medAge = data['housing_median_age']
medValue = data['median_house_value']
medData = data[['median_income', 'housing_median_age']]
pop = data['population']
import matplotlib.pyplot as plt
plt.figure(figsize = (20, 20))
plt.ylabel('median income')
plt.xlabel('median age')
plt.scatter(pop, medAge)

# %%
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import scipy.stats

# %%
res = scipy.stats.linregress(x = pop, y = medAge)

# %%
plt.scatter(pop, medAge)
plt.plot(pop, res.intercept + res.slope*pop, 'red')
